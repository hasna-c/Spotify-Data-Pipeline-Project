# %%
# !pip install spotipy
# Out:
# ...
#      ------------------------------------ 238.9/238.9 kB 160.8 kB/s eta 0:00:00
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#Authentication
client_credentials_manager = SpotifyClientCredentials(client_id="ffdeb02322a24ca8a6783a14b21081c8",client_secret="4abd0a5dddee4104a1d5cc1852bed4d4")

# %%
#object used for autherisation extract spotify API
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF"

# %%
playlist_link.split("/")
# Out:
# ['https:', '', 'open.spotify.com', 'playlist', '37i9dQZEVXbMDoHDwVN2tF']

# %%
playlist_URI = playlist_link.split("/")[-1]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
(data['items'])
# Out:
# [{'added_at': '2023-04-09T09:33:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#       'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#       'id': '5YGY8feqx7naU7z4HrwZM6',
#       'name': 'Miley Cyrus',
#       'type': 'artist',
#       'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
# ...

# %%
len(data['items'])
# Out:
# 50

# %%
data['items'][0]['track']['album']['id']
# Out:
# '0HiZ8fNXwJOQcrf5iflrdz'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Endless Summer Vacation'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-03-10'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 13

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/0HiZ8fNXwJOQcrf5iflrdz'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_urls = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id': album_id,'album_name': album_name,'album_release_date': album_release_date,
                     'album_total_tracks': album_total_tracks,'album_urls': album_urls
                    }
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '0HiZ8fNXwJOQcrf5iflrdz',
#   'album_name': 'Endless Summer Vacation',
#   'album_release_date': '2023-03-10',
#   'album_total_tracks': 13,
#   'album_urls': 'https://open.spotify.com/album/0HiZ8fNXwJOQcrf5iflrdz'},
#  {'album_id': '3Mm1P5CEEAiuJqBclr2EyU',
#   'album_name': 'Ella Baila Sola',
#   'album_release_date': '2023-03-16',
#   'album_total_tracks': 1,
#   'album_urls': 'https://open.spotify.com/album/3Mm1P5CEEAiuJqBclr2EyU'},
#  {'album_id': '1nrVofqDRs7cpWXJ49qTnP',
#   'album_name': 'SOS',
#   'album_release_date': '2022-12-08',
#   'album_total_tracks': 23,
#   'album_urls': 'https://open.spotify.com/album/1nrVofqDRs7cpWXJ49qTnP'},
#  {'album_id': '4kS7bSuU0Jm9LYMosFU2x5',
#   'album_name': 'MAÑANA SERÁ BONITO',
#   'album_release_date': '2023-02-24',
#   'album_total_tracks': 17,
#   'album_urls': 'https://open.spotify.com/album/4kS7bSuU0Jm9LYMosFU2x5'},
#  {'album_id': '6aBVGuOUEuX18rHxyDWbti',
#   'album_name': 'La Bebe (Remix)',
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2023-04-09T09:33:00Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#      'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#      'id': '5YGY8feqx7naU7z4HrwZM6',
#      'name': 'Miley Cyrus',
#      'type': 'artist',
#      'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
# ...

# %%
artist_list = []
for row in data ['items']:
    for key, value in row.items():
        if key == "track":
            for artists in value['artists']:
                artist_dict ={'artists_id': artists['id'],'artist_name': artists['name'],'external_url':artists['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artists_id': '5YGY8feqx7naU7z4HrwZM6',
#   'artist_name': 'Miley Cyrus',
#   'external_url': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6'},
#  {'artists_id': '0XeEobZplHxzM9QzFQWLiR',
#   'artist_name': 'Eslabon Armado',
#   'external_url': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR'},
#  {'artists_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artists_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'external_url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artists_id': '790FomKkXshlbRYZFtlgla',
#   'artist_name': 'KAROL G',
#   'external_url': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla'},
#  {'artists_id': '0EmeFodog0BfCgMzAIvKQp',
#   'artist_name': 'Shakira',
#   'external_url': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp'},
#  {'artists_id': '1NNRWkhwmcXRimFYSBpB1y',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id': song_id,'song_name': song_name,'song_duration': song_duration,'song_url': song_url,
                    'song_popularity': song_popularity,'song_added': song_added,'album_id': album_id,'artist_id': artist_id 
                    }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id               album_name album_release_date  \
# 0  0HiZ8fNXwJOQcrf5iflrdz  Endless Summer Vacation         2023-03-10
# 1  3Mm1P5CEEAiuJqBclr2EyU          Ella Baila Sola         2023-03-16
# 2  1nrVofqDRs7cpWXJ49qTnP                      SOS         2022-12-08
# 3  4kS7bSuU0Jm9LYMosFU2x5       MAÑANA SERÁ BONITO         2023-02-24
# 4  6aBVGuOUEuX18rHxyDWbti          La Bebe (Remix)         2023-03-17
#
#    album_total_tracks                                         album_urls
# 0                  13  https://open.spotify.com/album/0HiZ8fNXwJOQcrf...
# 1                   1  https://open.spotify.com/album/3Mm1P5CEEAiuJqB...
# 2                  23  https://open.spotify.com/album/1nrVofqDRs7cpWX...
# 3                  17  https://open.spotify.com/album/4kS7bSuU0Jm9LYM...
# 4                   2  https://open.spotify.com/album/6aBVGuOUEuX18rH...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            50 non-null     object
#  1   album_name          50 non-null     object
#  2   album_release_date  50 non-null     object
#  3   album_total_tracks  50 non-null     int64
#  4   album_urls          50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#                artists_id     artist_name  \
# 0  5YGY8feqx7naU7z4HrwZM6     Miley Cyrus
# 1  0XeEobZplHxzM9QzFQWLiR  Eslabon Armado
# 2  12GqGscKJx3aE4t07u7eVZ      Peso Pluma
# 3  7tYKF4w9nC0nq9CsPZTHyP             SZA
# 4  790FomKkXshlbRYZFtlgla         KAROL G
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/5YGY8feqx7n...
# 1  https://api.spotify.com/v1/artists/0XeEobZplHx...
# 2  https://api.spotify.com/v1/artists/12GqGscKJx3...
# 3  https://api.spotify.com/v1/artists/7tYKF4w9nC0...
# 4  https://api.spotify.com/v1/artists/790FomKkXsh...

# %%
artist_df = artist_df.drop_duplicates(subset=['artists_id'])

# %%
#song data frame
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id        song_name  song_duration  \
# 0  4DHcnVTT87F0zZhRPYmZ3B          Flowers         200600
# 1  3dnP0JxCgygwQH9Gm7q7nb  Ella Baila Sola         165671
# 2  1Qrg8KqiBpW07V7PNxwwwL        Kill Bill         153946
# 3  0DWdj2oZMBFSzRsi2Cvfzf              TQG         197933
# 4  2UW7JaomAMuX9pZrjVpHAU  La Bebe - Remix         234352
#
#                                             song_url  song_popularity  \
# 0  https://open.spotify.com/track/4DHcnVTT87F0zZh...               90
# 1  https://open.spotify.com/track/3dnP0JxCgygwQH9...               94
# 2  https://open.spotify.com/track/1Qrg8KqiBpW07V7...               95
# 3  https://open.spotify.com/track/0DWdj2oZMBFSzRs...               98
# 4  https://open.spotify.com/track/2UW7JaomAMuX9pZ...               92
#
#              song_added                album_id               artist_id
# 0  2023-04-09T09:33:00Z  0HiZ8fNXwJOQcrf5iflrdz  5YGY8feqx7naU7z4HrwZM6
# ...

# %%
album_df['album_release_date'] = pd.to_datetime(album_df['album_release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            49 non-null     object
#  1   album_name          49 non-null     object
#  2   album_release_date  49 non-null     datetime64[ns]
#  3   album_total_tracks  49 non-null     int64
#  4   album_urls          49 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.3+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   song_id          50 non-null     object
#  1   song_name        50 non-null     object
#  2   song_duration    50 non-null     int64
#  3   song_url         50 non-null     object
#  4   song_popularity  50 non-null     int64
#  5   song_added       50 non-null     datetime64[ns, UTC]
#  6   album_id         50 non-null     object
#  7   artist_id        50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
